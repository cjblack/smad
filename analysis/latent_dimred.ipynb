# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# WIP Notebook for dimensionality reduction on latent space

Z1 = latent_a
Z2 = latent_b

Z = np.vstack([Z1, Z2])
labels = np.array([0] * len(Z1) + [1] * len(Z2))


tsne = TSNE(n_components=3)
Z2 = tsne.fit_transform(Z)

Z2_a = Z2[labels == 0]
Z2_b = Z2[labels == 1]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(Z2_a[:,0], Z2_a[:, 1], Z2_a[:, 2], alpha=0.5, label='Data A')
ax.scatter(Z2_b[:,0], Z2_b[:, 1], Z2_b[:, 2], alpha=0.5, label='Data B')

plt.show()
